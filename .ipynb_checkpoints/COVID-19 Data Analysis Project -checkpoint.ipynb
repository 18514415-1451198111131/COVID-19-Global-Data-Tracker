# %%
import pandas as pd           # For data handling
import matplotlib.pyplot as plt  # For static plots
import seaborn as sns         # For statistical visualizations
import plotly.express as px   # For interactive plots
import geopandas as gpd       # For geospatial data

# %%
unc_df= pd.read_csv('full_grouped.csv')

# %%
#Performing Exploratory Data Analysis
unc_df.head()
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
# 2  2020-01-22        Algeria          0       0          0       0          0
# 3  2020-01-22        Andorra          0       0          0       0          0
# 4  2020-01-22         Angola          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe
# 2           0              0                 Africa
# 3           0              0                 Europe
# 4           0              0                 Africa

# %%
 # 🧾 Inspect dataset structure
unc_df.columns     # Check column names
unc_df.head()      # Preview the first few rows
unc_df.info()      # General info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35156 entries, 0 to 35155
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            35156 non-null  object
#  1   Country/Region  35156 non-null  object
#  2   Confirmed       35156 non-null  int64
#  3   Deaths          35156 non-null  int64
#  4   Recovered       35156 non-null  int64
#  5   Active          35156 non-null  int64
#  6   New cases       35156 non-null  int64
#  7   New deaths      35156 non-null  int64
#  8   New recovered   35156 non-null  int64
#  9   WHO Region      35156 non-null  object
# dtypes: int64(7), object(3)
# memory usage: 2.7+ MB

# %%
#Check for missing values
unc_df.isnull().sum()
# Out:
# Date              0
# Country/Region    0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# New cases         0
# New deaths        0
# New recovered     0
# WHO Region        0
# dtype: int64

# %%
#Clean the dataset
# Convert 'Date' column to datetime
unc_df['Date'] = pd.to_datetime(unc_df['Date'])

# %%
# Filter for selected countries
countries = ['US', 'Australia', 'South Korea', 'China', 'South Africa']
df_filtered = unc_df[unc_df['Country/Region'].isin(countries)]

# %%
# Drop rows with missing critical values
df_filtered = df_filtered.dropna(subset=['Confirmed', 'Deaths', 'Date'])

# %%
# Fill missing numeric data
num_cols = ['Recovered', 'Active', 'New cases', 'New deaths', 'New recovered']
df_filtered[num_cols] = df_filtered[num_cols].fillna(0)

# %%
# 📈 Exploratory Data Analysis (EDA)
# Plot total confirmed cases over time
plt.figure(figsize=(10,6))
for country in countries:
    data = df_filtered[df_filtered['Country/Region'] == country]
    plt.plot(data['Date'], data['Confirmed'], label=country)
plt.title('Total Confirmed COVID-19 Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot total deaths over time
plt.figure(figsize=(10,6))
for country in countries:
    data = df_filtered[df_filtered['Country/Region'] == country]
    plt.plot(data['Date'], data['Deaths'], label=country)
plt.title('Total Deaths Over Time')
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate and plot death rate over time (Deaths / Confirmed)
plt.figure(figsize=(10,6))
for country in countries:
    data = df_filtered[df_filtered['Country/Region'] == country].copy()
    data['Death Rate'] = data['Deaths'] / data['Confirmed']
    plt.plot(data['Date'], data['Death Rate'], label=country)
plt.title('COVID-19 Death Rate Over Time')
plt.xlabel('Date')
plt.ylabel('Death Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Bar chart: Compare new cases by country (latest date)
latest_date = df_filtered['Date'].max()
latest_data = df_filtered[df_filtered['Date'] == latest_date]
plt.figure(figsize=(8,6))
sns.barplot(data=latest_data, x='Country/Region', y='New cases')
plt.title(f'New Cases by Country on {latest_date.date()}')
plt.xlabel('Country')
plt.ylabel('New Cases')
plt.grid(True)
plt.show()

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\unc sam\anaconda3\lib\site-packages (1.37.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\unc sam\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\unc sam\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\unc sam\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in c:\users\unc sam\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\unc sam\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\unc sam\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\unc sam\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\unc sam\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\unc sam\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\unc sam\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\unc sam\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\unc sam\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\unc sam\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\unc sam\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\unc sam\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\unc sam\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\unc sam\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\unc sam\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\unc sam\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\unc sam\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\unc sam\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\unc sam\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\unc sam\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
# Dropdown for countries
country_dropdown = widgets.Dropdown(
    options=unc_df['Country/Region'].unique(),
    value='Kenya',
    description='Country:')

# %%
# Assuming unc_df is already defined with the Date column
min_date = unc_df['Date'].min()
max_date = unc_df['Date'].max()

# %%
# Create a date range slider
date_range = widgets.SelectionRangeSlider(options=[d.strftime('%Y-%m-%d') for d in pd.date_range(min_date, max_date)],
    index=(0, len(pd.date_range(min_date, max_date))-1),description='Date Range:',layout={'width': '800px'})

# %%
# Create a country dropdown (example, replace with your actual dropdown setup)
country_dropdown = widgets.Dropdown(
    options=['Country1', 'Country2', 'Country3'],  # Example options
    description='Country:',)

# %%
# Display the widgets
display(country_dropdown, date_range)
# Out:
# Dropdown(description='Country:', options=('Country1', 'Country2', 'Country3'), value='Country1')
# SelectionRangeSlider(description='Date Range:', index=(0, 187), layout=Layout(width='800px'), options=('2020-0…
